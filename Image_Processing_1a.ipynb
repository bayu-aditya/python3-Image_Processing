# %% [markdown]
# ----------
# #### TASK: Open the *dog_backpack.jpg* image from the DATA folder and display it in the notebook. Make sure to correct for the RGB order.

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
gambar = cv2.imread('DATA/dog_backpack.jpg')
gambar = cv2.cvtColor(gambar, cv2.COLOR_BGR2RGB)
gambar.shape
# Out:
# (1401, 934, 3)

# %% [markdown]
# #### TASK: Flip the image upside down and display it in the notebook.

# %%
gambar_flip = cv2.flip(gambar, flipCode = 0)

fig = plt.figure(figsize = (10,5))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)
ax1.imshow(gambar)
ax2.imshow(gambar_flip)
plt.show()

# %% [markdown]
# #### TASK: Draw an empty RED rectangle around the dogs face and display the image in the notebook.

# %%
gambar_rect = gambar.copy()
cv2.rectangle(gambar_rect, pt1=(200, 400), pt2=(600,700), 
              color = (255,0,0), thickness = 15)
plt.imshow(gambar_rect); plt.show()

# %% [markdown]
# #### TASK: Draw a BLUE TRIANGLE in the middle of the image. The size and angle is up to you, but it should be a triangle (three sides) in any orientation.

# %%
gambar_triangle = gambar.copy()
points = np.array([[250, 700],[400,400],[600,700]])
print(points.shape)
points = points.reshape(-1,1,2)
print(points.shape)

cv2.polylines(gambar_triangle, pts = [points], isClosed = True,
              color = (0,0,255), thickness = 15)
plt.imshow(gambar_triangle); plt.show()
# Out:
# (3, 2)
# (3, 1, 2)

# %% [markdown]
# ### BONUS TASK. Can you figure our how to fill in this triangle? It requires a different function that we didn't show in the lecture! See if you can use google search to find it.
#
# [CLICK ME FOR A DIRECT LINK TO THE HINT](https://docs.opencv.org/3.0-beta/modules/imgproc/doc/drawing_functions.html#fillpoly)

# %%
gambar_triangle = gambar.copy()
points = np.array([[250, 700],[400,400],[600,700]])
print(points.shape)
points = points.reshape(-1,1,2)
print(points.shape)

cv2.fillPoly(gambar_triangle, pts = [points], color = (0,0,255))
plt.imshow(gambar_triangle); plt.show()
# Out:
# (3, 2)
# (3, 1, 2)

# %% [markdown]
# #### TASK: (NOTE: YOU WILL NEED TO RUN THIS AS A SCRIPT). Create a script that opens the picture and allows you to draw empty red circles whever you click the RIGHT MOUSE BUTTON DOWN.

# %%
def fungsi_redcircle(event, x, y, flags, param):
    if event == cv2.EVENT_RBUTTONDOWN:
        cv2.circle(blank, center = (x,y), radius = 50, color = (255,0,0), thickness = 4)
        
blank = np.zeros((512, 512, 3), dtype = np.uint8)

cv2.namedWindow('red circle')
cv2.setMouseCallback('red circle', fungsi_redcircle)

while True:
    cv2.imshow('red circle', blank)
    if cv2.waitKey(20) & 0xFF == 27:
        break
        
cv2.destroyAllWindows()
